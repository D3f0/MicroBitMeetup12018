# %%
# !gcc mid2asc.c -o mid2asc

# %%
output = !mid2asc  music.mid

# %%
from collections import namedtuple
# BA    2   CR         0   TR  0   CH  1   NT  E'            3/4

Note = namedtuple('Note', 'ba n cr n0 tr trn ch chn nt note tempo')

# %%
from itertools import cycle

# %%
for line in output:
    for n, y in len(line):
# Out:
# format=0 tracks=1 division=960 <class 'str'>
#  <class 'str'>
# BA    1   CR         0   TR  0   CH 16   Text type 3: "untitled" <class 'str'>
# BA    1   CR         0   TR  0   CH 16   Text type 2: "Copyright � 2008 by " <class 'str'>
# BA    1   CR         0   TR  0   CH 16   Text type 1: "EB\n" <class 'str'>
# BA    1   CR         0   TR  0   CH 16   Time signature 4/4, clocks/mtick 24, crotchets/32ndnote 8 <class 'str'>
# BA    1   CR         0   TR  0   CH 16   Key G major <class 'str'>
# BA    1   CR         0   TR  0   CH 16   Tempo 100 <class 'str'>
# BA    1   CR         1   TR  0   CH  1   NT  E'              1   von=100 <class 'str'>
# BA    1   CR         2   TR  0   CH  1   NT  E'              1 <class 'str'>
# BA    1   CR         3   TR  0   CH  1   NT  E'              1 <class 'str'>
#  <class 'str'>
# BA    2   CR         0   TR  0   CH  1   NT  E'            3/4 <class 'str'>
# BA    2   CR       3/4   TR  0   CH  1   NT  B             1/4 <class 'str'>
# ...

# %%
notes = [l for l in notes if l[0] == 'BA']

# %%
notes
# Out:
# [['BA',
#   '1',
#   'CR',
#   '0',
#   'TR',
#   '0',
#   'CH',
#   '16',
#   'Text',
#   'type',
#   '3:',
#   '"untitled"'],
#  ['BA',
#   '1',
#   'CR',
#   '0',
#   'TR',
#   '0',
#   'CH',
#   '16',
#   'Text',
#   'type',
#   '2:',
#   '"Copyright',
#   '�',
#   '2008',
#   'by',
#   '"'],
#  ['BA',
#   '1',
#   'CR',
#   '0',
#   'TR',
#   '0',
#   'CH',
#   '16',
#   'Text',
#   'type',
#   '1:',
#   '"EB\\n"'],
#  ['BA',
#   '1',
#   'CR',
#   '0',
#   'TR',
#   '0',
#   'CH',
#   '16',
#   'Time',
#   'signature',
#   '4/4,',
#   'clocks/mtick',
#   '24,',
#   'crotchets/32ndnote',
#   '8'],
#  ['BA', '1', 'CR', '0', 'TR', '0', 'CH', '16', 'Key', 'G', 'major'],
#  ['BA', '1', 'CR', '0', 'TR', '0', 'CH', '16', 'Tempo', '100'],
#  ['BA', '1', 'CR', '1', 'TR', '0', 'CH', '1', 'NT', "E'", '1', 'von=100'],
#  ['BA', '1', 'CR', '2', 'TR', '0', 'CH', '1', 'NT', "E'", '1'],
#  ['BA', '1', 'CR', '3', 'TR', '0', 'CH', '1', 'NT', "E'", '1'],
# ...

# %%
re.findall?
# Out:
# Signature: re.findall(pattern, string, flags=0)
# Docstring:
# Return a list of all non-overlapping matches in the string.
#
# If one or more capturing groups are present in the pattern, return
# a list of groups; this will be a list of tuples if the pattern
# has more than one group.
#
# Empty matches are included in the result.
# File:      ~/.pyenv/versions/3.6.0/lib/python3.6/re.py
# Type:      function

# %%
# !mid2asc music.mid
# Out:
# format=0 tracks=1 division=960
#
# BA    1   CR         0   TR  0   CH 16   Text type 3: "untitled"
# BA    1   CR         0   TR  0   CH 16   Text type 2: "Copyright � 2008 by "
# BA    1   CR         0   TR  0   CH 16   Text type 1: "EB\n"
# BA    1   CR         0   TR  0   CH 16   Time signature 4/4, clocks/mtick 24, crotchets/32ndnote 8
# BA    1   CR         0   TR  0   CH 16   Key G major
# BA    1   CR         0   TR  0   CH 16   Tempo 100
# BA    1   CR         1   TR  0   CH  1   NT  E'              1   von=100
# BA    1   CR         2   TR  0   CH  1   NT  E'              1
# BA    1   CR         3   TR  0   CH  1   NT  E'              1
#
# BA    2   CR         0   TR  0   CH  1   NT  E'            3/4
# BA    2   CR       3/4   TR  0   CH  1   NT  B             1/4
# BA    2   CR         1   TR  0   CH  1   NT  B             1/2
# BA    2   CR     1+1/2   TR  0   CH  1   NT  B             1/2
# BA    2   CR         2   TR  0   CH  1   NT  C'            1/2
# ...
